# %%
# https://www.datacamp.com/courses/introduction-to-matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Course Description**
#
#
# Visualizing data in plots and figures exposes the underlying patterns in the data and provides insights. Good visualizations also help you communicate your data to others, and are useful to data analysts and other consumers of the data. In this course, you will learn how to use Matplotlib, a powerful Python data visualization library. Matplotlib provides the building blocks to create rich visualizations of many different kinds of datasets. You will learn how to create visualizations for different kinds of data and how to customize, automate, and share these visualizations.

# %% [markdown]
# # 1. Introduction to Matplotlib
#
# This chapter introduces the Matplotlib visualization library and demonstrates how to use it with data.

# %%
seattle_weather = pd.read_csv("seattle_weather.csv", index_col='DATE')
seattle_weather.tail(3)
# Out:
#           STATION                         NAME  ...  MLY-TMIN-STDDEV  MONTH
# DATE                                            ...
# 10    USW00094290  SEATTLE SAND PT WSFO, WA US  ...              1.8    Oct
# 11    USW00094290  SEATTLE SAND PT WSFO, WA US  ...              3.0    Nov
# 12    USW00094290  SEATTLE SAND PT WSFO, WA US  ...              2.3    Dec
#
# [3 rows x 80 columns]

# %%
seattle_weather.shape
# Out:
# (12, 80)

# %%
austin_weather = pd.read_csv("austin_weather.csv", index_col='DATE')
austin_weather.tail()
# Out:
#           STATION  ... MONTH
# DATE               ...
# 8     USW00013904  ...   Aug
# 9     USW00013904  ...   Sep
# 10    USW00013904  ...   Oct
# 11    USW00013904  ...   Nov
# 12    USW00013904  ...   Dec
#
# [5 rows x 67 columns]

# %%
austin_weather.shape
# Out:
# (12, 67)

# %% [markdown]
# ###Introduction to data visualization with Matplotlib

# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Call the show function to show the result
plt.show()

# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Plot MLY-PRCP-NORMAL from seattle_weather against MONTH
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])

# Call the show function
plt.show()

# %% [markdown]
# ###Customizing your plots

# %%
# Plot Seattle data, setting data appearance
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"],
        color='b', marker='o', linestyle='--')

# Plot Austin data, setting data appearance
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
        color='r', marker='v', linestyle='--')

# Call show to display the resulting plot
plt.show()

# %%
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])

# Customize the x-axis label
ax.set_xlabel("Time (months)")

# Customize the y-axis label
ax.set_ylabel("Average temperature (Fahrenheit degrees)")

# Add the title
ax.set_title("Weather patterns in Austin and Seattle")

# Display the figure
plt.show()

# %% [markdown]
# ### Small multiples

# %%
# Create a Figure and an array of subplots with 2 rows and 2 columns
fig, ax = plt.subplots(2, 2)

# Addressing the top left Axes as index 0, 0, plot Seattle precipitation
ax[0, 0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])

# In the top right (index 0,1), plot Seattle temperatures
ax[0, 1].plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])

# In the bottom left (1, 0) plot Austin precipitations
ax[1, 0].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])

# In the bottom right (1, 1) plot Austin temperatures
ax[1, 1].plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
# Create a figure and an array of axes: 2 rows, 1 column with shared y axis
fig, axes = plt.subplots(2, 1, sharey=True)

# Plot Seattle precipitation in the top axes
axes[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b')
axes[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], color='b', linestyle='--')
axes[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"], color='b', linestyle='--')

# Plot Austin precipitation in the bottom axes
axes[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r')
axes[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"], color='r', linestyle='--')
axes[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"], color='r', linestyle='--')

plt.show()

# %% [markdown]
# # 2. Plotting time-series
#
# Time series data is data that is recorded. Visualizing this type of data helps clarify trends and illuminates relationships between data.

# %% [markdown]
# ### Plotting time-series data

# %%
# Import pandas
import pandas as pd

# Read the data from file using read_csv
climate_change = pd.read_csv('climate_change.csv', parse_dates=["date"], index_col="date")

# %%
climate_change.tail()
# Out:
#                co2  relative_temp
# date
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(climate_change.index, climate_change['relative_temp'])

# Set the x-axis label
ax.set_xlabel('Time')

# Set the y-axis label 
ax.set_ylabel('Relative temperature (Celsius)')

# Show the figure
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

# Use plt.subplots to create fig and ax
fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies["co2"])

# Show the figure
plt.show()

# %% [markdown]
# ###Plotting time-series with different variables

# %%
import matplotlib.pyplot as plt

# Initalize a Figure and Axes
fig, ax = plt.subplots()

# Plot the CO2 variable in blue
ax.plot(climate_change.index, climate_change["co2"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature in red
ax2.plot(climate_change.index, climate_change["relative_temp"], color='red')

plt.show()

# %%
# Define a function called plot_timeseries
def plot_timeseries(axes, x, y, color, xlabel, ylabel):

  # Plot the inputs x,y in the provided color
  axes.plot(x, y, color=color)

  # Set the x-axis label
  axes.set_xlabel(xlabel)

  # Set the y-axis label
  axes.set_ylabel(ylabel, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', "Time (years)", "CO2 levels")

# Create a twin Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', "Time (years)", "Relative temperature (Celsius)")

plt.show()

# %% [markdown]
# ###Annotating time-series data

# %%
fig, ax = plt.subplots()

# Plot the relative temperature data
ax.plot(climate_change.index, climate_change['relative_temp'])

# Annotate the date at which temperatures exceeded 1 degree
ax.annotate(">1 degree", xy=(pd.Timestamp('2015-10-06'), 1))

plt.show()

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', "Time (years)", "CO2 levels")

# Create an Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', "Time (years)", "Relative temp (Celsius)")

# Annotate the point with relative temperature >1 degree
ax2.annotate(">1 degree", xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2), arrowprops={'arrowstyle':'->', 'color':'gray'})

plt.show()

# %% [markdown]
# # 3. Quantitative comparisons and statistical visualizations
#
# Visualizations can be used to compare data in a quantitative manner. This chapter explains several methods for quantitative visualizations.

# %%
import io
medals_str = '''
               Bronze  Gold  Silver
United_States      67   137      52
Germany            67    47      43
Great_Britain      26    64      55
Russia             35    50      28
China              35    44      30
France             21    20      55
Australia          25    23      34
Italy              24     8      38
Canada             61     4       4
Japan              34    17      13
'''
medals = pd.read_table(io.StringIO(medals_str), delim_whitespace=True)
medals
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   from ipykernel import kernelapp as app
#                Bronze  Gold  Silver
# United_States      67   137      52
# Germany            67    47      43
# Great_Britain      26    64      55
# Russia             35    50      28
# China              35    44      30
# France             21    20      55
# Australia          25    23      34
# Italy              24     8      38
# Canada             61     4       4
# Japan              34    17      13

# %%
medals.dtypes
# Out:
# Bronze    int64
# Gold      int64
# Silver    int64
# dtype: object

# %% [markdown]
# ###Quantitative comparisons: bar-charts

# %%
fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals["Gold"])

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel("Number of medals")

plt.show()

# %%
# Add bars for "Gold" with the label "Gold"
ax.bar(medals.index, medals["Gold"], label="Gold")

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals["Bronze"], bottom=medals["Gold"] + medals["Silver"], label="Bronze")

# Display the legend
ax.legend()

plt.show()

# %% [markdown]
# ###Quantitative comparisons: histograms

# %%
#@title
mens_rowing_ls = [[158,
  62,
  'Giovanni Abagnale',
  'M',
  21.0,
  198.0,
  90.0,
  'Italy',
  'ITA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Pairs",
  'Bronze'],
 [11648,
  6346,
  'Jrmie Azou',
  'M',
  27.0,
  178.0,
  71.0,
  'France',
  'FRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Double Sculls",
  'Gold'],
 [14871,
  8025,
  'Thomas Gabriel Jrmie Baroukh',
  'M',
  28.0,
  183.0,
  70.0,
  'France',
  'FRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Bronze'],
 [15215,
  8214,
  'Jacob Jepsen Barse',
  'M',
  27.0,
  188.0,
  73.0,
  'Denmark',
  'DEN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Silver'],
 [18441,
  9764,
  'Alexander Belonogoff',
  'M',
  26.0,
  187.0,
  90.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Silver'],
 [19227,
  10181,
  'Paul Bennett',
  'M',
  27.0,
  207.0,
  100.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [25068,
  13120,
  'Hamish Byron Bond',
  'M',
  30.0,
  189.0,
  89.0,
  'New Zealand',
  'NZL',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Pairs",
  'Gold'],
 [25568,
  13359,
  'Joshua "Josh" Booth',
  'M',
  25.0,
  190.0,
  93.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Silver'],
 [25638,
  13395,
  'Kjetil Borch',
  'M',
  26.0,
  193.0,
  84.0,
  'Norway',
  'NOR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Double Sculls",
  'Bronze'],
 [29397,
  15181,
  'Lawrence Brittain',
  'M',
  25.0,
  187.0,
  94.0,
  'South Africa',
  'RSA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Pairs",
  'Silver'],
 [30541,
  15743,
  'Kristoffer Brun',
  'M',
  28.0,
  175.0,
  70.0,
  'Norway',
  'NOR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Double Sculls",
  'Bronze'],
 [36723,
  18870,
  'Matteo Castaldo',
  'M',
  30.0,
  188.0,
  86.0,
  'Italy',
  'ITA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Bronze'],
 [43276,
  22307,
  'Thibault Colard',
  'M',
  24.0,
  187.0,
  70.0,
  'France',
  'FRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Bronze'],
 [54773,
  28068,
  'Marco Di Costanzo',
  'M',
  24.0,
  184.0,
  87.0,
  'Italy',
  'ITA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Pairs",
  'Bronze'],
 [58440,
  29899,
  'Felix Drahotta',
  'M',
  27.0,
  200.0,
  102.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [58935,
  30156,
  'Alexander Mah Owens Drysdale',
  'M',
  37.0,
  200.0,
  102.0,
  'New Zealand',
  'NZL',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Single Sculls",
  'Gold'],
 [59895,
  30664,
  'Joshua Dunkley-Smith',
  'M',
  27.0,
  194.0,
  98.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Silver'],
 [60169,
  30808,
  'Scott David Durant',
  'M',
  28.0,
  196.0,
  96.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [63602,
  32577,
  'Tnu Endrekson',
  'M',
  37.0,
  198.0,
  104.0,
  'Estonia',
  'EST',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Bronze'],
 [71367,
  36350,
  'Karsten Forsterling',
  'M',
  36.0,
  191.0,
  88.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Silver'],
 [79876,
  40549,
  'Cameron Girdlestone',
  'M',
  28.0,
  190.0,
  92.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Silver'],
 [82674,
  42000,
  'Matthew Anthony W. "Matt" Gotrel',
  'M',
  27.0,
  195.0,
  95.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [84101,
  42734,
  'Alexander John "Alex" Gregory',
  'M',
  32.0,
  198.0,
  97.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Gold'],
 [84812,
  43037,
  'Mindaugas Grikonis',
  'M',
  30.0,
  190.0,
  92.0,
  'Lithuania',
  'LTU',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Double Sculls",
  'Silver'],
 [85408,
  43300,
  'Hans Gruhne',
  'M',
  27.0,
  193.0,
  92.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Gold'],
 [87541,
  44384,
  'Mario-Elio Gyr',
  'M',
  31.0,
  187.0,
  76.0,
  'Switzerland',
  'SUI',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Gold'],
 [94037,
  47603,
  'Kaj Hendriks',
  'M',
  28.0,
  197.0,
  95.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [95919,
  48553,
  'Alexander "Alex" Hill',
  'M',
  23.0,
  194.0,
  92.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Silver'],
 [95976,
  48586,
  'Phelan Peter Hill',
  'M',
  37.0,
  172.0,
  55.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [99267,
  50232,
  'Pierre Houin',
  'M',
  22.0,
  182.0,
  74.0,
  'France',
  'FRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Double Sculls",
  'Gold'],
 [105630,
  53423,
  'Malte Jakschik',
  'M',
  23.0,
  194.0,
  93.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [105842,
  53547,
  'Andrei Jms',
  'M',
  34.0,
  184.0,
  90.0,
  'Estonia',
  'EST',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Bronze'],
 [108903,
  55069,
  'Eric Johannesen',
  'M',
  28.0,
  193.0,
  100.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [110948,
  56133,
  'Morten Jrgensen',
  'M',
  31.0,
  183.0,
  73.0,
  'Denmark',
  'DEN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Silver'],
 [115218,
  58380,
  'Shaun Keeling',
  'M',
  29.0,
  196.0,
  94.0,
  'South Africa',
  'RSA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Pairs",
  'Silver'],
 [128438,
  64676,
  'Andreas Kuffner',
  'M',
  29.0,
  196.0,
  94.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [132169,
  66517,
  'Matthew Keir "Matt" Langridge',
  'M',
  33.0,
  194.0,
  93.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [132723,
  66805,
  'Jacob Sgaard Larsen',
  'M',
  28.0,
  182.0,
  73.0,
  'Denmark',
  'DEN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Silver'],
 [141461,
  70979,
  'William Lockwood',
  'M',
  28.0,
  191.0,
  88.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Silver'],
 [141484,
  70992,
  'Matteo Lodo',
  'M',
  21.0,
  196.0,
  90.0,
  'Italy',
  'ITA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Bronze'],
 [142874,
  71687,
  'Constantine Michael Louloudis',
  'M',
  24.0,
  190.0,
  92.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Gold'],
 [143561,
  72059,
  'Robert Lcken',
  'M',
  31.0,
  199.0,
  95.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [150566,
  75551,
  'Damir Martin',
  'M',
  28.0,
  189.0,
  97.0,
  'Croatia',
  'CRO',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Single Sculls",
  'Silver'],
 [155284,
  77955,
  'James McRae',
  'M',
  29.0,
  193.0,
  93.0,
  'Australia',
  'AUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Silver'],
 [157885,
  79256,
  'Boaz Cornelius Meylink',
  'M',
  32.0,
  195.0,
  93.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [162497,
  81588,
  'Domenico Montrone',
  'M',
  30.0,
  189.0,
  97.0,
  'Italy',
  'ITA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Bronze'],
 [165984,
  83359,
  'Maximilian Munski',
  'M',
  28.0,
  195.0,
  96.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [166398,
  83571,
  'Eric Gordon Murray',
  'M',
  34.0,
  195.0,
  98.0,
  'New Zealand',
  'NZL',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Pairs",
  'Gold'],
 [168352,
  84598,
  'George Christopher Nash',
  'M',
  26.0,
  195.0,
  96.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Gold'],
 [171349,
  86104,
  'Simon Niepmann',
  'M',
  31.0,
  180.0,
  71.0,
  'Switzerland',
  'SUI',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Gold'],
 [175033,
  87939,
  'Hannes Ocik',
  'M',
  25.0,
  191.0,
  93.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [175069,
  87962,
  "Gary O'Donovan",
  'M',
  23.0,
  172.0,
  70.0,
  'Ireland',
  'IRL',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Double Sculls",
  'Silver'],
 [175070,
  87963,
  "Paul O'Donovan",
  'M',
  22.0,
  177.0,
  70.0,
  'Ireland',
  'IRL',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Double Sculls",
  'Silver'],
 [196006,
  98419,
  'Guillaume Louis  Benoit Raineau',
  'M',
  30.0,
  187.0,
  71.0,
  'France',
  'FRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Bronze'],
 [196086,
  98448,
  'Allar Raja',
  'M',
  33.0,
  190.0,
  95.0,
  'Estonia',
  'EST',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Bronze'],
 [196970,
  98886,
  'Thomas Matthew "Tom" Ransley',
  'M',
  30.0,
  198.0,
  101.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [198211,
  99523,
  'Peter "Pete" Reed',
  'M',
  35.0,
  197.0,
  100.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [198703,
  99780,
  'Maximilian Reinelt',
  'M',
  27.0,
  195.0,
  98.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [201228,
  101070,
  'Saulius Ritter',
  'M',
  27.0,
  202.0,
  110.0,
  'Lithuania',
  'LTU',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Double Sculls",
  'Silver'],
 [202833,
  101889,
  'Boudewijn Rell',
  'M',
  27.0,
  195.0,
  100.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [211029,
  105974,
  'William Spencer "Will" Satch',
  'M',
  27.0,
  198.0,
  100.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [211287,
  106100,
  'Martin Sauer',
  'M',
  33.0,
  169.0,
  55.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [211987,
  106423,
  'Mohamed Karim "Moe" Sbihi',
  'M',
  28.0,
  202.0,
  110.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Gold'],
 [213343,
  107131,
  'Richard Schmidt',
  'M',
  29.0,
  191.0,
  87.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Silver'],
 [213949,
  107434,
  'Lauritz Schoof',
  'M',
  25.0,
  195.0,
  98.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Gold'],
 [214534,
  107703,
  'Karl Schulze',
  'M',
  28.0,
  190.0,
  100.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Gold'],
 [214624,
  107750,
  'Simon Schrch',
  'M',
  25.0,
  186.0,
  75.0,
  'Switzerland',
  'SUI',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Gold'],
 [219503,
  110265,
  'Olivier Floris Johannes Siegelaar',
  'M',
  29.0,
  197.0,
  100.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [221462,
  111300,
  'Martin Sinkovi',
  'M',
  26.0,
  188.0,
  95.0,
  'Croatia',
  'CRO',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Double Sculls",
  'Gold'],
 [221464,
  111301,
  'Valent Sinkovi',
  'M',
  28.0,
  187.0,
  93.0,
  'Croatia',
  'CRO',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Double Sculls",
  'Gold'],
 [224775,
  112904,
  'Franck Robert Bernard Solforosi',
  'M',
  31.0,
  184.0,
  70.0,
  'France',
  'FRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Bronze'],
 [230399,
  115643,
  'Are Weierholt Strandli',
  'M',
  27.0,
  181.0,
  69.0,
  'Norway',
  'NOR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Double Sculls",
  'Bronze'],
 [233799,
  117258,
  'Ondej Synek',
  'M',
  33.0,
  199.0,
  105.0,
  'Czech Republic',
  'CZE',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Single Sculls",
  'Bronze'],
 [234967,
  117835,
  'Kaspar Taimsoo',
  'M',
  29.0,
  194.0,
  95.0,
  'Estonia',
  'EST',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Bronze'],
 [242890,
  121635,
  'Lucas Tramr',
  'M',
  26.0,
  183.0,
  75.0,
  'Switzerland',
  'SUI',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Gold'],
 [243432,
  121915,
  'Andrew "Andy" Triggs Hodge',
  'M',
  37.0,
  192.0,
  97.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Gold'],
 [244737,
  122530,
  'Olaf Karl Tufte',
  'M',
  40.0,
  193.0,
  94.0,
  'Norway',
  'NOR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Double Sculls",
  'Bronze'],
 [246036,
  123195,
  'Dirk Uittenbogaard',
  'M',
  26.0,
  199.0,
  93.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [251892,
  126144,
  'Pieter Gilles "Mechiel" Versluis',
  'M',
  29.0,
  197.0,
  95.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [252281,
  126330,
  'Giuseppe Vicino',
  'M',
  23.0,
  195.0,
  95.0,
  'Italy',
  'ITA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxless Fours",
  'Bronze'],
 [258859,
  129601,
  'Phillipp Wende',
  'M',
  31.0,
  199.0,
  90.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Quadruple Sculls",
  'Gold'],
 [260260,
  130259,
  'Peter Noel Jan Wiersum',
  'M',
  31.0,
  173.0,
  55.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [260338,
  130298,
  'Tone Wieten',
  'M',
  22.0,
  201.0,
  102.0,
  'Netherlands',
  'NED',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Coxed Eights",
  'Bronze'],
 [261973,
  131072,
  'Kasper Winther Jrgensen',
  'M',
  31.0,
  182.0,
  73.0,
  'Denmark',
  'DEN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Rowing',
  "Rowing Men's Lightweight Coxless Fours",
  'Silver']]

print("length of mens_rowing_ls: ", len(mens_rowing_ls))
# Out:
# length of mens_rowing_ls:  84

# %%
mens_rowing = pd.DataFrame(mens_rowing_ls, columns = ['Unnamed: 0', 'ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'])
mens_rowing.tail()
# Out:
#     Unnamed: 0      ID  ...                                   Event   Medal
# 79      252281  126330  ...              Rowing Men's Coxless Fours  Bronze
# 80      258859  129601  ...           Rowing Men's Quadruple Sculls    Gold
# 81      260260  130259  ...               Rowing Men's Coxed Eights  Bronze
# 82      260338  130298  ...               Rowing Men's Coxed Eights  Bronze
# 83      261973  131072  ...  Rowing Men's Lightweight Coxless Fours  Silver
#
# [5 rows x 16 columns]

# %%
mens_rowing_idx = [[    8,   735,   885,   912,  1059,  1105,  1351,  1378,  1383,  1582,  1645,  1963,  2347,  2904,  3117,  3142,  3187,  3200,  3383,  3750,  4137,  4293,  4363,  4394,  4417,  4521,
             4810,  4901,  4905,  5023,  5363,  5381,  5482,  5557,  5800,  6412,  6582,  6610,  7028,  7031,  7100,  7140,  7495,  7731,  7860,  8157,  8300,  8339,  8475,  8628,  8771,  8775,
             8776,  9883,  9889,  9946,  9995, 10010, 10140, 10240, 10637, 10646, 10680, 10728, 10749, 10766, 10767, 11054, 11152, 11153, 11302, 11531, 11679, 11734, 12174, 12192, 12254, 12346,
            12679, 12701, 13011, 13071, 13077, 13158]]

mens_rowing = mens_rowing.set_index(mens_rowing_idx)

# %%
# sanity check
mens_rowing.tail()
# Out:
#        Unnamed: 0      ID  ...                                   Event   Medal
# 12701      252281  126330  ...              Rowing Men's Coxless Fours  Bronze
# 13011      258859  129601  ...           Rowing Men's Quadruple Sculls    Gold
# 13071      260260  130259  ...               Rowing Men's Coxed Eights  Bronze
# 13077      260338  130298  ...               Rowing Men's Coxed Eights  Bronze
# 13158      261973  131072  ...  Rowing Men's Lightweight Coxless Fours  Silver
#
# [5 rows x 16 columns]

# %%
#@title
mens_gymnastics_ls = [[794,
  455,
  'Denis Mikhaylovich Ablyazin',
  'M',
  24.0,
  161.0,
  62.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Silver'],
 [796,
  455,
  'Denis Mikhaylovich Ablyazin',
  'M',
  24.0,
  161.0,
  62.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Horse Vault",
  'Silver'],
 [797,
  455,
  'Denis Mikhaylovich Ablyazin',
  'M',
  24.0,
  161.0,
  62.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Rings",
  'Bronze'],
 [18577,
  9829,
  'David Sagitovich Belyavsky',
  'M',
  24.0,
  165.0,
  55.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Silver'],
 [18579,
  9829,
  'David Sagitovich Belyavsky',
  'M',
  24.0,
  165.0,
  55.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Parallel Bars",
  'Bronze'],
 [53763,
  27572,
  'Deng Shudi',
  'M',
  24.0,
  163.0,
  58.0,
  'China',
  'CHN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Bronze'],
 [89224,
  45219,
  'Fabian Hambchen',
  'M',
  28.0,
  164.0,
  62.0,
  'Germany',
  'GER',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Horizontal Bar",
  'Gold'],
 [101753,
  51457,
  'Diego Matias Hyplito',
  'M',
  30.0,
  170.0,
  68.0,
  'Brazil',
  'BRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Floor Exercise",
  'Silver'],
 [114515,
  57997,
  'Ryohei Kato',
  'M',
  22.0,
  162.0,
  54.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Gold'],
 [128700,
  64787,
  'Nikolay Yulyevich Kuksenkov',
  'M',
  27.0,
  172.0,
  65.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Silver'],
 [137853,
  69285,
  'Danell Johan Leyva Gonzalez',
  'M',
  24.0,
  170.0,
  68.0,
  'United States',
  'USA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Parallel Bars",
  'Silver'],
 [137854,
  69285,
  'Danell Johan Leyva Gonzalez',
  'M',
  24.0,
  170.0,
  68.0,
  'United States',
  'USA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Horizontal Bar",
  'Silver'],
 [139275,
  69955,
  'Lin Chaopan',
  'M',
  20.0,
  163.0,
  60.0,
  'China',
  'CHN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Bronze'],
 [140788,
  70677,
  'Liu Yang',
  'M',
  21.0,
  162.0,
  61.0,
  'China',
  'CHN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Bronze'],
 [149540,
  75010,
  'Arthur Nory Oyakawa Mariano',
  'M',
  22.0,
  169.0,
  65.0,
  'Brazil',
  'BRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Floor Exercise",
  'Bronze'],
 [167240,
  84014,
  'Alexander Michael "Alex" Naddour',
  'M',
  25.0,
  170.0,
  70.0,
  'United States',
  'USA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Pommelled Horse",
  'Bronze'],
 [167469,
  84138,
  'Nikita Vladimirovich Nagorny',
  'M',
  19.0,
  166.0,
  67.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Silver'],
 [187216,
  94094,
  'Eleftherios Petrounias',
  'M',
  25.0,
  164.0,
  62.0,
  'Greece',
  'GRE',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Rings",
  'Gold'],
 [199788,
  100351,
  'Ri Se-Gwang',
  'M',
  31.0,
  155.0,
  54.0,
  'North Korea',
  'PRK',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Horse Vault",
  'Gold'],
 [218755,
  109869,
  'Kenzo Shirai',
  'M',
  19.0,
  162.0,
  51.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Gold'],
 [218757,
  109869,
  'Kenzo Shirai',
  'M',
  19.0,
  162.0,
  51.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Horse Vault",
  'Bronze'],
 [223676,
  112342,
  'Louis Antoine Smith',
  'M',
  27.0,
  184.0,
  76.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Pommelled Horse",
  'Silver'],
 [230629,
  115758,
  'Ivan Alekseyevich Stretovich',
  'M',
  19.0,
  170.0,
  59.0,
  'Russia',
  'RUS',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Silver'],
 [236062,
  118359,
  'Yusuke Tanaka',
  'M',
  26.0,
  166.0,
  58.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Gold'],
 [245736,
  123056,
  'Kohei Uchimura',
  'M',
  27.0,
  160.0,
  54.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Individual All-Around",
  'Gold'],
 [245737,
  123056,
  'Kohei Uchimura',
  'M',
  27.0,
  160.0,
  54.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Gold'],
 [251779,
  126096,
  'Oleh Yuriyovych Verniaiev',
  'M',
  22.0,
  161.0,
  55.0,
  'Ukraine',
  'UKR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Individual All-Around",
  'Silver'],
 [251783,
  126096,
  'Oleh Yuriyovych Verniaiev',
  'M',
  22.0,
  161.0,
  55.0,
  'Ukraine',
  'UKR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Parallel Bars",
  'Gold'],
 [259829,
  130071,
  'Max Antony Whitlock',
  'M',
  23.0,
  167.0,
  56.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Individual All-Around",
  'Bronze'],
 [259831,
  130071,
  'Max Antony Whitlock',
  'M',
  23.0,
  167.0,
  56.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Floor Exercise",
  'Gold'],
 [259835,
  130071,
  'Max Antony Whitlock',
  'M',
  23.0,
  167.0,
  56.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Pommelled Horse",
  'Gold'],
 [261563,
  130874,
  'Nile Wilson',
  'M',
  20.0,
  166.0,
  60.0,
  'Great Britain',
  'GBR',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Horizontal Bar",
  'Bronze'],
 [264454,
  132340,
  'Koji Yamamuro',
  'M',
  27.0,
  159.0,
  58.0,
  'Japan',
  'JPN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Gold'],
 [266171,
  133174,
  'You Hao',
  'M',
  24.0,
  162.0,
  60.0,
  'China',
  'CHN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Bronze'],
 [267709,
  133931,
  'Arthur Nabarrete Zanetti',
  'M',
  26.0,
  156.0,
  61.0,
  'Brazil',
  'BRA',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Rings",
  'Silver'],
 [268713,
  134433,
  'Zhang Chenglong',
  'M',
  27.0,
  173.0,
  65.0,
  'China',
  'CHN',
  '2016 Summer',
  2016,
  'Summer',
  'Rio de Janeiro',
  'Gymnastics',
  "Gymnastics Men's Team All-Around",
  'Bronze']]

print("length of mens_gymnastics_ls: ", len(mens_gymnastics_ls))
# Out:
# length of mens_gymnastics:  36

# %%
mens_gymnastics = pd.DataFrame(mens_gymnastics_ls, columns = ['Unnamed: 0', 'ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'])

# %%
mens_gymnastics_idx = [[   58,    60,    61,  1066,  1068,  2838,  4600,  5150,  5748,  6421,  6832,  6833,  6923,  6990,  7450,  8398,  8414,  9410, 10076, 11004, 11006, 11252, 11540, 11796, 12324, 12325,
            12663, 12667, 13048, 13050, 13054, 13146, 13291, 13402, 13502, 13551]]

# %%
mens_gymnastics = mens_gymnastics.set_index(mens_gymnastics_idx)
mens_gymnastics.tail()
# Out:
#        Unnamed: 0      ID  ...                             Event   Medal
# 13146      261563  130874  ...   Gymnastics Men's Horizontal Bar  Bronze
# 13291      264454  132340  ...  Gymnastics Men's Team All-Around    Gold
# 13402      266171  133174  ...  Gymnastics Men's Team All-Around  Bronze
# 13502      267709  133931  ...            Gymnastics Men's Rings  Silver
# 13551      268713  134433  ...  Gymnastics Men's Team All-Around  Bronze
#
# [5 rows x 16 columns]

# %%
fig, ax = plt.subplots()
# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing["Weight"])

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics["Weight"])

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel("Weight (kg)")

# Set the y-axis label to "# of observations"
ax.set_ylabel("# of observations")

plt.show()

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing["Weight"], histtype='step', label="Rowing", bins=5)

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics["Weight"], histtype='step', label="Gymnastics", bins=5)

ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()
plt.show()

# %% [markdown]
# ###Statistical plotting

# %%
fig, ax = plt.subplots()

# Add a bar for the rowing "Height" column mean/std
ax.bar("Rowing", mens_rowing["Height"].mean(), yerr=mens_rowing["Height"].std())

# Add a bar for the gymnastics "Height" column mean/std
ax.bar("Gymnastics", mens_gymnastics["Height"].mean(), yerr=mens_gymnastics["Height"].std())

# Label the y-axis
ax.set_ylabel("Height (cm)")

plt.show()

# %%
fig, ax = plt.subplots()

# Add the Seattle temperature data in each month with standard deviation error bars
ax.errorbar(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"], yerr=seattle_weather["MLY-TAVG-STDDEV"])

# Add the Austin temperature data in each month with standard deviation error bars
ax.errorbar(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"], yerr=austin_weather["MLY-TAVG-STDDEV"])

# Set the y-axis label
ax.set_ylabel("Temperature (Fahrenheit)")

plt.show()

# %%
fig, ax = plt.subplots()

# Add a boxplot for the "Height" column in the DataFrames
ax.boxplot([mens_rowing["Height"], mens_gymnastics["Height"]])

# Add x-axis tick labels:
ax.set_xticklabels(["Rowing", "Gymnastics"])

# Add a y-axis label
ax.set_ylabel("Height (cm)")

plt.show()

# %% [markdown]
# ###Quantitative comparisons: scatter plots

# %%
fig, ax = plt.subplots()

# Add data: "co2" on x-axis, "relative_temp" on y-axis
ax.scatter(climate_change["co2"], climate_change["relative_temp"])

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %%
fig, ax = plt.subplots()

# Add data: "co2", "relative_temp" as x-y, index as color
ax.scatter(climate_change["co2"], climate_change["relative_temp"], c=climate_change.index)

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %% [markdown]
# # 4. Sharing visualizations with others
#
#
# This chapter shows you how to share your visualizations with others: how to save your figures as files, how to adjust their look and feel, and how to automate their creation based on input data.

# %% [markdown]
# ###Preparing your figures to share with others

# %%
# Use the "ggplot" style and create new Figure/Axes
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
# Use the "Solarize_Light2" style and create new Figure/Axes
plt.style.use('Solarize_Light2')
fig, ax = plt.subplots()
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %% [markdown]
# ###Saving your visualizations

# %% [markdown]
# ####Saving a file several times

# %%
# Show the figure
plt.show()

# %%
# Save as a PNG file
fig.savefig('my_figure.png')

# %%
# Save as a PNG file with 300 dpi
fig.savefig('my_figure_300dpi.png', dpi=300)

# %% [markdown]
# ####Save a figure with different sizes

# %%
# Set figure dimensions and save as a PNG
fig.set_size_inches([3, 5])
fig.savefig('figure_3_5.png')

# %%
# Set figure dimensions and save as a PNG
fig.set_size_inches([5, 3])
fig.savefig('figure_5_3.png')

# %% [markdown]
# ###Automating figures from data

# %%
# Extract the "Sport" column
sports_column = summer_2016_medals["Sport"]

# Find the unique values of the "Sport" column
sports = sports_column.unique()

# Print out the unique sports values
print(sports)

# %%
fig, ax = plt.subplots()

# Loop over the different sports branches
for sport in sports:
  # Extract the rows only for this sport
  sport_df = summer_2016_medals[summer_2016_medals["Sport"] == sport]
  # Add a bar for the "Weight" mean with std y error bar
  ax.bar(sport, sport_df["Weight"].mean(), yerr=sport_df["Weight"].std())

ax.set_ylabel("Height (cm)")
ax.set_xticklabels(sports, rotation=90)

# Save the figure to file
fig.savefig("sports_weights.png")
